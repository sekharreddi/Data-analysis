# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# we use head function to show first 5 records in the dataset

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# we use tail function to show last 5 records in the dataset

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# SHAPE function is used to know how much dat is present in terms of rows and columns

# %%
data.shape
# Out:
# (8807, 12)

# %% [markdown]
# SIZE Function is used to show total number of elements

# %%
data.size
# Out:
# 105684

# %% [markdown]
# COLUMNS function is used to show each column name

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# DTYPES function is used to show data type of each column

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# INFO() function is mostly used to find Non-Null count

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ***Find if any duplicate records are present or not.If any remove the duplicates***

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# To find any duplicate records

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# To remove any duplicate records we have to use drop function : data.drop_duplicates(inplace =True)

# %% [markdown]
# Find if any NULL values in any column

# %% [markdown]
# True means NULL value present. False means No NULL value

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %% [markdown]
# To show count of NULL values in each column we use sum function

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Showing NULL Value count using heatmap.

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **For 'House of cards', what is the show id and who is the director of this show?**

# %% [markdown]
# To retrive data we use isin() function

# %%
data[data['title'].isin(['Zoom'])]
# Out:
#      show_id   type title      director  \
# 8805   s8806  Movie  Zoom  Peter Hewitt
#
#                                                    cast        country  \
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#             date_added  release_year rating duration  \
# 8805  January 11, 2020          2006     PG   88 min
#
#                                listed_in  \
# 8805  Children & Family Movies, Comedies
#
#                                             description
# 8805  Dragged from civilian life, a former superhero...

# %% [markdown]
# **In which year highest number of TV Shows and Movies are released? show with Bar Graph.**

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# changing datatype of date_added to datetime by using **to_datetime**

# %%
data['date_added']=pd.to_datetime(data['date_added'])

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %% [markdown]
# value_count function is used to count the entries

# %%
data['date_added'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: date_added, dtype: int64

# %%
data['date_added'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# **how many movies and TV shows are in the dataset?Show with Bar Grah**

# %% [markdown]
# To group all unique items of a column and show their count

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# **Bar graph**

# %%
sns.countplot(data['type'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-561fa5b5e34f> in <cell line: 1>()
# ----> 1 sns.countplot(data['type'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
# ...

# %% [markdown]
# filtering
#
#
# show all the movies that were released in year 2000

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
data.describe(include='object')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country rating  duration  \
# count                 7982           7976   8803      8804
# unique                7692            748     17       220
# top     David Attenborough  United States  TV-MA  1 Season
# freq                    19           2818   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# unique                                               8775
# ...

# %%
for col in data.describe(include='object').columns:
  print(col)
  print(data[col].unique())
  print('_'*50)
# Out:
# show_id
# ['s1' 's2' 's3' ... 's8805' 's8806' 's8807']
# __________________________________________________
# type
# ['Movie' 'TV Show']
# __________________________________________________
# title
# ['Dick Johnson Is Dead' 'Blood & Water' 'Ganglands' ... 'Zombieland'
#  'Zoom' 'Zubaan']
# __________________________________________________
# director
# ['Kirsten Johnson' nan 'Julien Leclercq' ... 'Majid Al Ansari'
#  'Peter Hewitt' 'Mozez Singh']
# __________________________________________________
# cast
# [nan
#  'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng'
#  'Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera'
#  ...
# ...

# %%
data[((data['type']=='Movie')& (data['release_year']==2000))]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
data.groupby('release_year').release_year.count()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: release_year, Length: 74, dtype: int64

# %% [markdown]
# show only the TV Shows that were released in india only.

# %%
data[((data['type']=='TV Show')& (data['country']=='India'))]['show_id']
# Out:
# 4          s5
# 39        s40
# 50        s51
# 66        s67
# 69        s70
#         ...
# 8173    s8174
# 8235    s8236
# 8321    s8322
# 8349    s8350
# 8775    s8776
# Name: show_id, Length: 79, dtype: object

# %% [markdown]
# Show top 10 directors, who give highest numbe of TV Shows and movies to netflix

# %%
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# Show all th records,where type is Movie and listed_in Comedies or country is United Kingdom

# %%
data[(data['type']=='Movie') & ((data['listed_in']=='Comedies') | (data['country']=='United Kingdom') )].head()
# Out:
#     show_id   type                          title        director  \
# 27      s28  Movie                      Grown Ups    Dennis Dugan
# 152    s153  Movie  Janoskians: Untold and Untrue    Brett Weiner
# 182    s183  Movie    Welcome Home Roscoe Jenkins  Malcolm D. Lee
# 233    s234  Movie                    Count Me In         Mark Lo
# 292    s293  Movie                        Quartet  Dustin Hoffman
#
#                                                   cast         country  \
# 27   Adam Sandler, Kevin James, Chris Rock, David S...   United States
# 152  Jai Brooks, Luke Brooks, James Yammouni, Danie...   United States
# 182  Martin Lawrence, James Earl Jones, Joy Bryant,...   United States
# 233                                                NaN  United Kingdom
# 292  Maggie Smith, Tom Courtenay, Billy Connolly, P...  United Kingdom
#
#     date_added  release_year rating duration  \
# 27  2021-09-20          2010  PG-13  103 min
# 152 2021-09-01          2016  TV-MA   88 min
# ...

# %% [markdown]
# In how many movies/TV Shows Tom cruise was cast?

# %%
data[data['cast']=='Adam Sandler']
# Out:
#      show_id   type                    title     director          cast  \
# 4482   s4483  Movie  ADAM SANDLER 100% FRESH  Steve Brill  Adam Sandler
#
#             country date_added  release_year rating duration        listed_in  \
# 4482  United States 2018-10-23          2018  TV-MA   74 min  Stand-Up Comedy
#
#                                             description
# 4482  From "Heroes" to "Ice Cream Ladies" – Adam San...

# %%
data[data['cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data[data['cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-8b73098fb4c1> in <cell line: 1>()
# ----> 1 data[data['cast'].str.contains('Tom Cruise')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
# -> 3797         if com.is_bool_indexer(key):
#    3798             return self._getitem_bool_array(key)
#    3799
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# It is showing ther is null values in the cast column so, we need to drop null values.To drop NULL values we use DROPNA function

# %%
data=data.dropna()

# %%
data[data['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating duration                   listed_in  \
# 341  2021-08-01          1999      R  189 min  Dramas, Independent Movies
# 1254 2021-03-01          1988      R  134 min      Classic Movies, Dramas
#
#                                             description
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...

# %% [markdown]
# unique Rating for a partical column

# %%
data['rating'].nunique()
# Out:
# 14

# %%
data['rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# How many movies got the 'TV-14' rating, in canada

# %%
data[((data['type']=='Movie') &(data['rating']=='TV-14') & (data['country']=='Canada'))]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# 157                       Danishka Esterhazy
# 2769                  Ellen Page, Ian Daniel
# 3424                     Jean-François Blais
# 5973                         Michael Kennedy
# ...

# %% [markdown]
# to get how many records exists in a dataset we use shape function

# %%
data[((data['type']=='Movie') &(data['rating']=='TV-14') & (data['country']=='Canada'))].shape
# Out:
# (10, 12)

# %%
data[((data['type']=='TV SHOW') &(data['rating']=='R') & (data['release_year']>2018))]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data[((data['type']=='TV SHOW') &(data['rating']=='R'))]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []
